# %% [markdown]
# # Image Detection model Through image

# %%
#Import Required library
import cv2
import os
import matplotlib.pyplot as plt

img_dir = "C:/Users/karti/Tsa Project/images/img/"

# Load the cascade
face_cascade = cv2.CascadeClassifier(img_dir+"haarcascade_frontalface_default.xml")
# Read the input image
for i in os.listdir(img_dir):
    if i.endswith(".png"):
        img = cv2.imread(img_dir+i)

        # Convert into grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
         # Detect faces
        faces = face_cascade.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=5)
        # Draw rectangle around the faces
        for (x, y, w, h) in faces:
            cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
        # Display the output
        plt.imshow(img)
        plt.show()

# %% [markdown]
# # Face Detection through Web Cam

# %%
#Capture video
cap = cv2.VideoCapture(0)

while True:
    #capture Frame by Frame
    ret,frame=cap.read()
    
    # Convert into grayscale
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    
    # Detect faces
    faces = face_cascade.detectMultiScale(gray,scaleFactor=1.2,minNeighbors=5)
    #Draw rectange around face
    for(x,y,w,h) in faces:
        print(x,y,w,h)
        roi_gray=gray[y:y+h, x:x+w]
        img_item = "my-image.png"
        cv2.imwrite(img_item, roi_gray)
        

    #Display The resuting Frame
    cv2.imshow('frame',frame)
    # Stop if q is pressed  
    if cv2.waitKey(20) & 0xFF == ord('q'):
        break

#When Everything is completed,release the captured Photo
cap.release()
cv2.destroyAllWindows()
# Out:
# 271 249 225 225
# 259 210 252 252
# 258 165 255 255
# 256 157 253 253
# 256 148 252 252
# 257 150 253 253
# 263 159 247 247
# 263 161 247 247
# 272 163 234 234
# 269 166 238 238
# 274 168 233 233
# 270 169 238 238
# 270 169 241 241
# 272 173 237 237
# 272 174 240 240
# 270 178 244 244
# 271 181 245 245
# 272 181 246 246
# 273 181 245 245
# 272 182 246 246
# 271 180 246 246
# 268 176 252 252
